# %% [markdown]
# ## Source:  data.world
# ## Date created:  May 2017

# %%
import pandas as pd

# %%
raw = pd.read_csv('Tinder Millennial Match Rate Dataset.csv').drop([3,4,5])

# %%
#Segmenting wanted rows
male=raw.iloc[3:6]
female=raw.iloc[6:9]

# %%
import matplotlib.pyplot as plt
import numpy as np
f, ax = plt.subplots(1, figsize=(25,18))

#Manualy create list of values after viewing results. Still looking for the proper way to do it
yes = np.array([21.3, 19.8])
no = np.array([52.8, 48.7])
dont = np.array([25.9, 31.5])
ind =np.arange(2)
#Format bar chart
plt.bar(ind, yes, width=0.3, label='yes', color='gold', bottom=no+dont)
plt.bar(ind, no, width=0.3, label='no', color='silver', bottom=dont)
plt.bar(ind, dont, width=0.3, label='dont', color='#CD853F')
#Setting label and legends
plt.legend(('Yes','No','Not a user'), fontsize=30)
plt.title('Have you met someone on Tinder', fontsize=35)
plt.ylabel('Percentage',fontsize=30)
plt.xlabel('Gender', fontsize=30)
plt.xticks(range(2), labels=['Male','Female'], rotation='horizontal', fontsize='25')
plt.yticks(fontsize='25')

plt.show()
